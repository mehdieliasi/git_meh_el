# %% [markdown]
# <a href="https://colab.research.google.com/github/mehdieliasi/git_meh_el/blob/master/EDA_Demos_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

insurance = pd.read_csv("/content/insurance.csv")

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
import seaborn as sns

# %%
sns.histplot(insurance['charges'])
sns.despine()

# %%
sns.boxplot(x=insurance['charges'])
sns.despine()

# %%
sns.boxenplot(x=insurance['charges'])
sns.despine()

# %%
sns.histplot(x=insurance['age'])
sns.despine()

# %%
sns.histplot(x=insurance['bmi'])
sns.despine()

# %%
import matplotlib.pyplot as plt
insurance['smoker'].value_counts().plot.bar()
plt.show()

# %%
insurance['region'].value_counts().plot.bar()
plt.show()

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
insurance.groupby(by='smoker')['charges'].mean().sort_values().plot.barh();

# %%
insurance.corr(numeric_only=True)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(insurance.corr(numeric_only=True),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.scatterplot(insurance,x='age',y='charges');

# %%
sns.scatterplot(insurance,x='age',y='charges',hue='smoker');

# %% [markdown]
# #**Feature-Feature corrolation**

# %%
sns.scatterplot(insurance,x='age',y='bmi',);

# %%
insurance['age'].corr(insurance['bmi'])
# Out:
# 0.1092718815485352

# %%
insurance.groupby('smoker')['age'].mean().plot.bar();

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
sns.pairplot(insurance,hue='smoker');

# %%
sns.pairplot(insurance,hue='smoker',corner=True,diag_kind='kde');

# %%
sns.lmplot(insurance,x='age',y='charges',hue='smoker');

# %% [markdown]
# ### Correlation

# %%
import numpy as np
import seaborn as sns
xx = np.array([-0.51, 51.2])
yy = np.array([0.33, 51.6])
means = [xx.mean(), yy.mean()]
stds = [xx.std() / 3, yy.std() / 3]
corr = -0.25       # correlation
covs = [
    [stds[0]**2, stds[0]*stds[1]*corr],
    [stds[0]*stds[1]*corr, stds[1]**2]
]

m = np.random.multivariate_normal(means, covs, 1000).T

import pandas as pd

df = pd.DataFrame(m).T
df.columns = ["X", "Y"]
df.head()

sns.scatterplot(df, x="X", y="Y")

sns.despine()

# %% [markdown]
# ### Feature - Target Relationships

# %%
sns.scatterplot(data=insurance, x="age", y="price")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2c88dd964649> in <cell line: 1>()
# ----> 1 sns.scatterplot(data=insurance, x="age", y="price")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# --> 391         super().__init__(data=data, variables=variables)
#     392
#     393         self.legend = legend
#
# ...
